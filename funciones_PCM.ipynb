# %% [markdown]
# <a href="https://colab.research.google.com/github/mirellac17/PCM_python/blob/main/funciones_PCM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Funciones en Python
# Una función agrupa un código para reutilizarlo multiples veces
#
#
#
# ```
# def nombreFuncion(arg1,arg2):
#   tarea 1
#   tarea 2
#   return resultado
# ```
#
# Una función puede retornar un resultado o puede ejecutar tareas y no mostrar un resultado (por ejemplo, una función que cree un nuevo archivo o imagen![minimos-cuadrados.png](data:image/png;base64,...![minimos-cuadrados.png](data:image/png;base64,...![minimos-cuadrados.png](data:image/png;base64,...))))

# %% [markdown]
# **Ejemplo de mínimos cuadrados**
#
# Mínimos cuadrados es una técnica que permite calcular los parámetros de una recta de modo que se minimiza el error cuadrático. Los parámetros a calcular son la pendiente de la recta y la intersección con el eje vertical.
# ![imagen.png](data:image/png;base64,...)

# %%
#funcion minimos cuadras y r

# %% [markdown]
# Expresiones Lambda

# %% [markdown]
# #Librerias
# En Python, una librería es una colección de funciones orientadas a cumplir un conjunto de tareas específicas. Existen librerías orientadas para realizar cálculos matemáticos, analizar texto, trabajar con imágenes o audio, extraer información de sitios web, etc. Exploraremos algunas de las librerías más usadas.

# %% [markdown]
# ## Librería math y cmath
# La librería math se usa para realizar operaciones matemáticas. Posee una gran variedad de funciones de propósito general.

# %% [markdown]
# Ejemplo: la población de una especie de insectos crece siguiendo la siguiente ecuación logística.
#
# $P(t)=\frac{5500}{1+25e^{-0.04t}}$
#
# Donde $P(t)$ es el número de insectos en el tiempo $t$ en meses.

# %% [markdown]
# Agrupemos como una función el código anterior:

# %% [markdown]
# Ejemplo: La función distribucion normal está dada por
#
# $f(x)=\frac{1}{\sigma \sqrt{2\pi}}e^{-\frac{(x-\mu)^{2}}{2\sigma^{2}}}$

# %% [markdown]
# Sugiera funciones matemáticas que sean de su utilidad e interés (funciones matemáticas en economía, administración, ingenierías, biología, etc.)

# %%
#función de su interes

# %% [markdown]
# ## Libreria random
# la librería random permite generar números aleatorios y realizar operaciones que involucre números aleatorios como elegir uno elemento al azar, barajar un conjunto de elementos, etc.

# %%
#barajar

# %% [markdown]
# A continuación haremos un ejemplo de simular el juego de la ruleta con diferentes variaciones en la apuesta. El modelo está simplificado y es posible modificarlo para incluir información de interés.

# %%
### Ejemplo de ruleta.

# %% [markdown]
# ## Libreria os
# La librería OS permite realizar operaciones para interactuar con el sistema operativo como crear archivos, carpetas, explorar directorios, etc.
